# %% [markdown]
# # 03 · Analysis
#
# Auswertung & Charts — Städtevergleich, Kaufkraft-Score

# %%
import pandas as pd
import plotly.express as px
import sqlite3

conn = sqlite3.connect('../data/cost_of_living.db')
