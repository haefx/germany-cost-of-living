# %% [markdown]
# # 02 · Data Cleaning
#
# Pandas Cleaning — Duplikate, Nullwerte, Spalten normalisieren

# %%
import pandas as pd
from pathlib import Path

RAW = Path('../data/raw')
PROCESSED = Path('../data/processed')
PROCESSED.mkdir(parents=True, exist_ok=True)
