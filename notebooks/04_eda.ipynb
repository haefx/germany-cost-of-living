# %% [markdown]
# # 04 · Exploratory Data Analysis
#
# Verteilungen, Ausreißer, Korrelationen

# %%
import pandas as pd
import plotly.express as px
import sqlite3

conn = sqlite3.connect('../data/cost_of_living.db')
