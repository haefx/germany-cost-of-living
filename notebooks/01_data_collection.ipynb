# %% [markdown]
# # 01 · Data Collection
#
# Destatis CSV, Bundesagentur für Arbeit, BBSR Wohnatlas API

# %%
import requests
import pandas as pd
from pathlib import Path

RAW = Path('../data/raw')
RAW.mkdir(parents=True, exist_ok=True)
